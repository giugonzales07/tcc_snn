# %%
# Imports
# pip install kagglehub[pandas-datasets]
#import kagglehub
#from kagglehub import KaggleDatasetAdapter
import os
import random
from glob import glob
import cv2 
import matplotlib.pylab as plt
import seaborn as sns
import pandas as pd
import numpy as np


import snntorch as snn
from snntorch import spikeplot as splt
from snntorch import spikegen

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms, models

from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix
from sklearn.metrics import classification_report

import argparse
#import torch
#import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
#from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
from collections import Counter

# from codecarbon import EmissionsTracker
from carbontracker.tracker import CarbonTracker
# Out:
# c:\Users\giueg\.virtualenvs\TCC_25-OGy0qkdu\Lib\site-packages\torch\cuda\__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %% [markdown]
# # DATA

# %%
class CustomImageDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx].astype(np.uint8)
        label = self.labels[idx]
        if self.transform:
            img = self.transform(img)
        return img, label

# Load the data(images)
x_npz = np.load("../../data/x_images_arrays_2_class.npz")
X = x_npz["arr_0"]
y_npz = np.load("../../data/y_labels_arrays_2_class.npz")
Y = y_npz["arr_0"]

print("x = ", np.array(X).shape)
print("Y = ", np.array(Y).shape)

# Separete the data into train and test sets
# 80% train, 20% test
x_train_old, x_test, y_train_old, y_test = train_test_split(X, Y, test_size=0.2,random_state=1, stratify=Y)

x_train_aux = np.load("../../data/x_images_arrays_under_train_2_class.npz")
x_train = x_train_aux["arr_0"]
y_train_aux = np.load("../../data/y_labels_arrays_under_train_2_class.npz")
y_train = y_train_aux["arr_0"]

#x_test, x_val, y_test, y_val = train_test_split(x_temp, y_temp, test_size=0.5, random_state=1, stratify=y_temp)

print("\nForma dos dados de treino:", np.array(x_train).shape) # (3045, 128, 128, 3)
print("Distribuição train antes:", Counter(y_train)) #np.int64(0): 2435, np.int64(2): 402, np.int64(1): 208
#print(np.array(x_val).shape)
print("Forma dos dados de teste:", np.array(x_test).shape) # (762, 128, 128, 3)
print("Distribuição test antes:", Counter(y_test)) #np.int64(0): 609, np.int64(2): 101, np.int64(1): 52

# Transform the data to tensor
# Define a transform
transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Grayscale(num_output_channels=3),
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                std=[0.229, 0.224, 0.225])])

# Apply the transform to the data
dataset_train = CustomImageDataset(x_train, y_train, transform=transform)
#dataset_val = CustomImageDataset(x_val, y_val, transform=transform)
dataset_test = CustomImageDataset(x_test, y_test, transform=transform)

img, label = dataset_train[0]
print("\nForma do img e label:", img.shape, label) # [grayscale=1, size=128, size=128] label=0 ('Nothing')
print("Quantidade dados de treino:", dataset_train.__len__()) # 610 images
#print(dataset_val.__len__()) # 0 images
print("Quantidade dados de teste:", dataset_test.__len__()) # 762 images

# Load into the DataLoader
batch_size = 32

train_loader = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
#val_loader = DataLoader(dataset_val, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True)
# Out:
# x =  (3547, 128, 128, 3)
# Y =  (3547,)
#
# Forma dos dados de treino: (804, 128, 128, 3)
# Distribuição train antes: Counter({np.int64(0): 402, np.int64(1): 402})
# Forma dos dados de teste: (710, 128, 128, 3)
# Distribuição test antes: Counter({np.int64(0): 609, np.int64(1): 101})
#
# Forma do img e label: torch.Size([3, 224, 224]) 0
# Quantidade dados de treino: 804
# Quantidade dados de teste: 710

# %% [markdown]
# # NETWORK

# %% [markdown]
# ### Define

# %%
# Define the network

# Already defined in the previous cell
# batch_size = 32
# train_loader / val_loader / test_loader
num_steps = 50

dtype = torch.float
# Use GPU if available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Network Architecture 
num_inputs = 128*128
num_hidden = 1000
num_outputs = 2 # classes

# Temporal Dynamics
# num_steps = 25
#beta = 0.95

densenet = models.densenet121(pretrained=True)

# Congelar todos os parâmetros
for param in densenet.parameters():
    param.requires_grad = False

# Substituir e destravar apenas a última camada
densenet.classifier = nn.Linear(densenet.classifier.in_features, num_outputs)
for param in densenet.classifier.parameters():
    param.requires_grad = True


# Load the network onto CUDA if available
net = densenet.to(device)
# Out:
# c:\Users\giueg\.virtualenvs\TCC_25-OGy0qkdu\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\giueg\.virtualenvs\TCC_25-OGy0qkdu\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Metrics
# Accuracy
# pass data into the network, sum the spikes over time
# and compare the neuron with the highest number of spikes
# with the target

def print_batch_accuracy(data, targets, train=False):
    output = net(data)
    _, idx = output.max(1)
    acc = np.mean((targets == idx).detach().cpu().numpy())

    if train:
        print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
    else:
        print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")

def train_printer():
    print(f"Epoch {epoch}, Iteration {iter_counter}")
    print(f"Train Set Loss: {loss_hist[counter]:.2f}")
    print(f"Test Set Loss: {test_loss_hist[counter]:.2f}")
    print_batch_accuracy(data, targets, train=True)
    print_batch_accuracy(test_data, test_targets, train=False)
    print("\n")

# Função para calcular métricas
def calculate_metrics(y_true, y_pred):
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='macro') # average = 'weighted' | 'micro' | 'macro'
    return precision, recall, f1

# loss
# 1. Contar quantos exemplos de cada classe existem no dataset
# targets_list = []

# # Percorre todo o conjunto de treino para pegar os rótulos
# for _, targets in train_loader:
#     targets_list.extend(targets.tolist())

# class_counts = Counter(targets_list)
# total_samples = sum(class_counts.values())

# # 2. Calcular o peso inverso à frequência (quanto menos amostras, maior o peso)
# num_classes = len(class_counts)
# class_weights = []

# for i in range(num_classes):
#     count = class_counts[i]
#     weight = total_samples / (num_classes * count)
#     class_weights.append(weight)

# # 3. Criar tensor e mover para o mesmo dispositivo da rede
# class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

# 4. Redefinir a função de perda com pesos
# loss = nn.CrossEntropyLoss(weight=class_weights)

# Total samples
# total = 402 + 208 + 402

# # Frequência relativa inversa
# w0 = total / (3 * 402)
# w1 = total / (3 * 208)
# w2 = total / (3 * 402)

# # Tensor com pesos
# weights = torch.tensor([w0, w1, w2], dtype=torch.float).to(device)

# # Loss ponderado
# loss = nn.CrossEntropyLoss(weight=weights)

# Class-Balanced Loss
# beta = 0.999
# class_counts = [402, 208, 402]
# effective_num = [(1 - beta) / (1 - beta ** count) for count in class_counts]
# weights = torch.tensor(effective_num, dtype=torch.float).to(device)
# loss = nn.CrossEntropyLoss(weight=weights)

# class FocalLoss(nn.Module):
#     def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
#         super(FocalLoss, self).__init__()
#         self.alpha = alpha
#         self.gamma = gamma
#         self.reduction = reduction

#     def forward(self, inputs, targets):
#         ce_loss = F.cross_entropy(inputs, targets, reduction='none', weight=self.alpha)
#         pt = torch.exp(-ce_loss)
#         focal_loss = ((1 - pt) ** self.gamma) * ce_loss

#         if self.reduction == 'mean':
#             return focal_loss.mean()
#         elif self.reduction == 'sum':
#             return focal_loss.sum()
#         else:
#             return focal_loss


# Class-Balanced Loss
beta = 0.95
class_counts = [402, 101]
effective_num = [(1 - beta) / (1 - beta ** count) for count in class_counts]
weights = torch.tensor(effective_num, dtype=torch.float).to(device)
loss = nn.CrossEntropyLoss(weight=weights)

# loss = FocalLoss(alpha=weights, gamma=2.0)
# loss = nn.CrossEntropyLoss()  # Sem pesos, pois o dataset já está balanceado

# optimizer
optimizer = torch.optim.Adam(net.classifier.parameters(), lr=5e-4)

# %% [markdown]
# ### Training Loop

# %%
# # Training loop
# num_epochs = 16
# loss_hist = []
# test_loss_hist = []
# counter = 0

# # Outer training loop
# for epoch in range(num_epochs):
#     iter_counter = 0
#     train_batch = iter(train_loader)
    
#     # Minibatch training loop
#     for data, targets in train_batch:
#         #print(epoch, iter_counter, counter)
#         data = data.to(device)
#         targets = targets.to(device)

#         # forward pass
#         net.train()
#         #spike_data = spikegen.latency(data, num_steps=num_steps, tau=1, threshold=0.001, clip=True, normalize=True, linear=True)
#         #print(f"Spike data size (latency 2): {spike_data.size()}")

#         output = net(data)

#         # Calculate loss
#         loss_val = loss(output, targets)

#         # Gradient calculation + weight update
#         optimizer.zero_grad()
#         loss_val.backward()
#         optimizer.step()

#         # Store loss history for future plotting
#         loss_hist.append(loss_val.item())

#         # Test set
#         with torch.no_grad():
#             net.eval()
#             test_data, test_targets = next(iter(test_loader))
#             test_data = test_data.to(device)
#             test_targets = test_targets.to(device)

#             # Test set forward pass
#             test_output = net(test_data)

#             # Test set loss
#             test_loss = loss(test_output, test_targets)
#             test_loss_hist.append(test_loss.item())

#             # Print train/test loss/accuracy
#             if counter % 32 == 0:
#                 train_printer()
#             counter += 1
#             iter_counter += 1
# Out:
# Epoch 0, Iteration 0
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 59.38%
# Test set accuracy for a single minibatch: 25.00%
#
#
# Epoch 0, Iteration 32
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 50.00%
# Test set accuracy for a single minibatch: 56.25%
#
#
# Epoch 1, Iteration 26
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 50.00%
#
#
# Epoch 2, Iteration 20
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 40.62%
#
#
# Epoch 3, Iteration 14
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 43.75%
#
#
# Epoch 4, Iteration 8
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 62.50%
# Test set accuracy for a single minibatch: 12.50%
#
#
# Epoch 5, Iteration 2
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 31.25%
#
#
# Epoch 5, Iteration 34
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 28.12%
#
#
# Epoch 6, Iteration 28
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 59.38%
#
#
# Epoch 7, Iteration 22
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 62.50%
#
#
# Epoch 8, Iteration 16
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 28.12%
#
#
# Epoch 9, Iteration 10
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 53.12%
#
#
# Epoch 10, Iteration 4
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 37.50%
#
#
# Epoch 10, Iteration 36
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 68.75%
#
#
# Epoch 11, Iteration 30
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 68.75%
#
#
# Epoch 12, Iteration 24
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 34.38%
#
#
# Epoch 13, Iteration 18
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 46.88%
#
#
# Epoch 14, Iteration 12
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 65.62%
#
#
# Epoch 15, Iteration 6
# Train Set Loss: 0.00
# Test Set Loss: 0.00
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 34.38%

# %%
PATH = '../../models/densenet_cnn_30_2_class_under_class_weights_only_output_codecarbon.pth'

# %%
# Training loop new
num_epochs = 30
loss_hist = []
test_loss_hist = []
counter = 0

# Early stopping parameters
best_f1 = 0
epochs_no_improve = 0
early_stop_patience = 20  # quantas épocas esperar sem melhoria

# tracker = EmissionsTracker()
# tracker.start()

# Configurar o CarbonTracker
tracker = CarbonTracker(
    epochs=num_epochs,  # Total de épocas (definido no seu código original)
    epochs_before_pred=1,  # Medir energia na primeira época e prever para as demais
    monitor_epochs=-1,  # -1 significa monitorar todas as épocas
    update_interval=1,  # Intervalo de atualização em segundos
    log_dir="./carbon_logs"  # Diretório para salvar logs
    # log_level=1  # Nível de verbosidade (1 = info, 2 = debug)
)

# Outer training loop
for epoch in range(num_epochs):
    tracker.epoch_start()

    iter_counter = 0
    train_batch = iter(train_loader)
    
    # Minibatch training loop
    for data, targets in train_batch:
        #print(epoch, iter_counter, counter)
        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        #spike_data = spikegen.latency(data, num_steps=num_steps, tau=1, threshold=0.001, clip=True, normalize=True, linear=True)
        #print(f"Spike data size (latency 2): {spike_data.size()}")

        output = net(data)

        # Calculate loss
        loss_val = loss(output, targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(test_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_output = net(test_data)

            # Test set loss
            test_loss = loss(test_output, test_targets)
            test_loss_hist.append(test_loss.item())

            # Print train/test loss/accuracy
            #if counter % 32 == 0:
                #train_printer()
            counter += 1
            iter_counter += 1
    
    # Early stopping check
    net.eval()
    all_preds = []
    all_targets = []

    with torch.no_grad():
        for data_2, targets_2 in test_loader:
            data_2 = data_2.to(device)
            targets_2 = targets_2.to(device)

            test_output_2 = net(data_2)
            _, predicted_2 = test_output_2.max(1)

            all_preds.extend(predicted_2.cpu().numpy())
            all_targets.extend(targets_2.cpu().numpy())

    # Calcular F1-score para early stopping
    precision, recall, f1 = calculate_metrics(all_targets, all_preds)
    print(f"\n[Epoch {epoch+1}] F1-score: {f1:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f}")

    # Early Stopping com base no F1-score
    if f1 > best_f1:
        best_f1 = f1
        epochs_no_improve = 0
        torch.save(net.state_dict(), PATH)
        print("🟢 Novo melhor modelo salvo!")
    else:
        epochs_no_improve += 1
        print(f"🔸 Sem melhoria. Épocas sem progresso: {epochs_no_improve}/{early_stop_patience}")

    tracker.epoch_end()

    if epochs_no_improve >= early_stop_patience:
        print(f"\n⛔ Early stopping ativado após {epoch+1} épocas. Melhor F1-score: {best_f1:.4f}")
        break


emissions = tracker.stop()  # Finalizar e obter emissões totais
print(f"Emissões totais estimadas: {emissions} kgCO2eq")

# emissions = tracker.stop()
# print(f"Emissões estimadas: {emissions} kgCO2eq")
# Out:
# CarbonTracker: INFO - Detected CPU: AMD Ryzen 5 5500U with Radeon Graphics
# CarbonTracker: WARNING - No matching TDP found for CPU: AMD Ryzen 5 5500U with Radeon Graphics. Using average TDP of 35.61W at 50% utilization as fallback.
# CarbonTracker: The following components were found: CPU with device(s) AMD Ryzen 5 5500U with Radeon Graphics.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
#
# [Epoch 1] F1-score: 0.3173 | Precision: 0.5128 | Recall: 0.5192
# 🟢 Novo melhor modelo salvo!
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: Live carbon intensity could not be fetched at detected location: Bauru, São Paulo, BR. Defaulted to average carbon intensity for BR in 2023 of 98.35 gCO2/kWh. at detected location: Bauru, São Paulo, BR.
# CarbonTracker:
# Predicted consumption for 30 epoch(s):
# 	Time:	1:20:26
# 	Energy:	0.075429041568 kWh
# 	CO2eq:	7.418313483083 g
# 	This is equivalent to:
# 	0.069007567284 km travelled by car
#
# [Epoch 2] F1-score: 0.2714 | Precision: 0.5192 | Recall: 0.5219
# 🔸 Sem melhoria. Épocas sem progresso: 1/20
#
# [Epoch 3] F1-score: 0.4529 | Precision: 0.5147 | Recall: 0.5300
# 🟢 Novo melhor modelo salvo!
#
# [Epoch 4] F1-score: 0.3902 | Precision: 0.5124 | Recall: 0.5238
# 🔸 Sem melhoria. Épocas sem progresso: 1/20
#
# [Epoch 5] F1-score: 0.5136 | Precision: 0.5310 | Recall: 0.5561
# 🟢 Novo melhor modelo salvo!
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
#
# [Epoch 6] F1-score: 0.5329 | Precision: 0.5420 | Recall: 0.5725
# 🟢 Novo melhor modelo salvo!
#
# [Epoch 7] F1-score: 0.4226 | Precision: 0.5281 | Recall: 0.5559
# 🔸 Sem melhoria. Épocas sem progresso: 1/20
#
# [Epoch 8] F1-score: 0.4476 | Precision: 0.5244 | Recall: 0.5499
# 🔸 Sem melhoria. Épocas sem progresso: 2/20
#
# [Epoch 9] F1-score: 0.4066 | Precision: 0.5576 | Recall: 0.6039
# 🔸 Sem melhoria. Épocas sem progresso: 3/20
#
# [Epoch 10] F1-score: 0.5194 | Precision: 0.5352 | Recall: 0.5635
# 🔸 Sem melhoria. Épocas sem progresso: 4/20
#
# [Epoch 11] F1-score: 0.5051 | Precision: 0.5368 | Recall: 0.5719
# 🔸 Sem melhoria. Épocas sem progresso: 5/20
#
# [Epoch 12] F1-score: 0.5386 | Precision: 0.5446 | Recall: 0.5749
# 🟢 Novo melhor modelo salvo!
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
#
# [Epoch 13] F1-score: 0.5611 | Precision: 0.5574 | Recall: 0.5822
# 🟢 Novo melhor modelo salvo!
#
# [Epoch 14] F1-score: 0.4789 | Precision: 0.5461 | Recall: 0.5944
# 🔸 Sem melhoria. Épocas sem progresso: 1/20
#
# [Epoch 15] F1-score: 0.5263 | Precision: 0.5431 | Recall: 0.5792
# 🔸 Sem melhoria. Épocas sem progresso: 2/20
#
# [Epoch 16] F1-score: 0.5143 | Precision: 0.5390 | Recall: 0.5743
# 🔸 Sem melhoria. Épocas sem progresso: 3/20
#
# [Epoch 17] F1-score: 0.4973 | Precision: 0.5491 | Recall: 0.6001
# 🔸 Sem melhoria. Épocas sem progresso: 4/20
#
# [Epoch 18] F1-score: 0.5630 | Precision: 0.5610 | Recall: 0.5946
# 🟢 Novo melhor modelo salvo!
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
#
# [Epoch 19] F1-score: 0.4728 | Precision: 0.5437 | Recall: 0.5895
# 🔸 Sem melhoria. Épocas sem progresso: 1/20
#
# [Epoch 20] F1-score: 0.4426 | Precision: 0.5597 | Recall: 0.6161
# 🔸 Sem melhoria. Épocas sem progresso: 2/20
#
# [Epoch 21] F1-score: 0.4651 | Precision: 0.5506 | Recall: 0.6028
# 🔸 Sem melhoria. Épocas sem progresso: 3/20
#
# [Epoch 22] F1-score: 0.4659 | Precision: 0.5597 | Recall: 0.6201
# 🔸 Sem melhoria. Épocas sem progresso: 4/20
#
# [Epoch 23] F1-score: 0.4587 | Precision: 0.5536 | Recall: 0.6078
# 🔸 Sem melhoria. Épocas sem progresso: 5/20
#
# [Epoch 24] F1-score: 0.4929 | Precision: 0.5502 | Recall: 0.6026
# 🔸 Sem melhoria. Épocas sem progresso: 6/20
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
#
# [Epoch 25] F1-score: 0.4672 | Precision: 0.5513 | Recall: 0.6044
# 🔸 Sem melhoria. Épocas sem progresso: 7/20
#
# [Epoch 26] F1-score: 0.5203 | Precision: 0.5552 | Recall: 0.6099
# 🔸 Sem melhoria. Épocas sem progresso: 8/20
#
# [Epoch 27] F1-score: 0.4765 | Precision: 0.5565 | Recall: 0.6151
# 🔸 Sem melhoria. Épocas sem progresso: 9/20
#
# [Epoch 28] F1-score: 0.4845 | Precision: 0.5529 | Recall: 0.6084
# 🔸 Sem melhoria. Épocas sem progresso: 10/20
#
# [Epoch 29] F1-score: 0.5132 | Precision: 0.5494 | Recall: 0.5983
# 🔸 Sem melhoria. Épocas sem progresso: 11/20
#
# [Epoch 30] F1-score: 0.4890 | Precision: 0.5501 | Recall: 0.6026
# 🔸 Sem melhoria. Épocas sem progresso: 12/20
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: Average carbon intensity during training was 98.35 gCO2/kWh at detected location: Bauru, São Paulo, BR.
# CarbonTracker:
# Actual consumption for 29 epoch(s):
# 	Time:	1:14:32
# 	Energy:	0.069902507776 kWh
# 	CO2eq:	6.874788611399 g
# 	This is equivalent to:
# 	0.063951521967 km travelled by car
# CarbonTracker: Finished monitoring.
# Emissões totais estimadas: None kgCO2eq

# %%
# Código extra para salvar o modelo
# PATH = '../../models/densenet_cnn_8_under_class_weights_over.pth'
# torch.save(net.state_dict(), PATH)
# print(f"Modelo salvo com sucesso em: {PATH}")
# Out:
# Modelo salvo com sucesso em: ../../models/ann_full_4_under.pth

# %%
# Carregar melhor modelo após o treinamento
net.load_state_dict(torch.load(PATH))
net.eval()
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1024, out_features=2, bias=True)
# )

# %% [markdown]
# ### Metrics

# %%
# Plot Loss
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist)
plt.plot(test_loss_hist)
plt.title("Loss Curves")
plt.legend(["Train Loss", "Test Loss"])
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
# Análise detalhada no conjunto de teste
import torch
import torch.nn as nn
from collections import defaultdict
import numpy as np

def register_activation_hooks(model, layer_types=(nn.Linear, nn.Conv2d)):
    activations = defaultdict(list)  # activations[layer_name] -> list of tensors per batch

    hooks = []

    def make_hook(name):
        def hook(module, input, output):
            # output shape: (batch, features, ...) -> vamos achatar por unidade de neurônio
            out = output.detach().cpu()
            # se conv2d, colapsa HxW para contar neurônios por mapa de feature
            if out.dim() > 2:
                # out shape -> (B, C, H, W) -> tomamos media espacial por neurônio (ou somar se preferir)
                # Para contar neurônios ativos, tratamos cada canal como "neurônio" e usa-se max/mean
                # Aqui optamos por max sobre HxW para considerar se alguma posição ativa => neurônio ativo
                out_per_neuron = out.view(out.size(0), out.size(1), -1).max(dim=2).values
            else:
                out_per_neuron = out  # (B, features)
            activations[name].append(out_per_neuron)  # list de (B, features)
        return hook

    for name, module in model.named_modules():
        if isinstance(module, layer_types):
            h = module.register_forward_hook(make_hook(name))
            hooks.append(h)

    def remove_hooks():
        for h in hooks:
            h.remove()

    return activations, remove_hooks

def compute_active_stats_from_activations(activations):
    """
    activations: dict layer_name -> list of tensors (each tensor shape (B, features))
    retorna estatísticas:
      - active_count_layer: dict layer_name -> np.array shape (N_samples,)
      - active_mean_layer: dict layer_name -> float
      - mean_global_active: float
    """
    active_count_layer = {}
    active_mean_pos_layer = {}
    active_mean_layer = {}
    sparsity_layer = {}
    # primeiro concatenar todas batches por layer
    for layer, list_tensors in activations.items():
        if len(list_tensors) == 0:
            continue
        all_t = torch.cat(list_tensors, dim=0)  # (N_total, features)
        # contagem de neurônios ativos por amostra (valor > 0)
        active_mask = (all_t > 0)
        active_counts = active_mask.sum(dim=1).numpy()  # (N_samples,)
        active_count_layer[layer] = active_counts

        # média de neurônios ativos por amostra
        active_mean_layer[layer] = float(active_counts.mean())

        # média das ativações apenas onde > 0 (intensidade)
        pos_values = all_t[all_t > 0]
        active_mean_pos_layer[layer] = float(pos_values.mean().item()) if pos_values.numel() > 0 else 0.0

        # sparsity
        total_neurons = all_t.size(1)
        sparsity_layer[layer] = 1.0 - (active_counts.mean() / total_neurons)

    # global per sample
    # assumir que todas layers tem N_samples iguais e ordenadas
    layers = list(active_count_layer.keys())
    counts_matrix = np.stack([active_count_layer[L] for L in layers], axis=0)  # (n_layers, N_samples)
    global_active_per_sample = counts_matrix.sum(axis=0)
    mean_global_active = float(global_active_per_sample.mean())

    return {
        "active_count_layer": active_count_layer,
        "active_mean_layer": active_mean_layer,
        "active_mean_pos_layer": active_mean_pos_layer,
        "sparsity_layer": sparsity_layer,
        "global_active_per_sample": global_active_per_sample,
        "mean_global_active": mean_global_active,
        "layers": layers
    }

# %%
# Inferência
# Medir por neurônios ativos
activations, remove_hooks = register_activation_hooks(net)

# Função para calcular métricas
def calculate_metrics(y_true, y_pred):
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='macro') # average = 'weighted' | 'micro' | 'macro'
    return precision, recall, f1

# Criar um novo tracker só para inferência
inference_tracker = CarbonTracker(
    epochs=1,               # só uma "época" (inferência completa)
    epochs_before_pred=1,   # medir direto
    monitor_epochs=-1,      # medir todas
    update_interval=1,
    log_dir="./carbon_logs_inference"
)

inference_tracker.epoch_start()  # início da medição

# Listas para armazenar previsões e rótulos verdadeiros
all_preds = []
all_targets = []

# Avaliação do modelo
total = 0
correct = 0

with torch.no_grad():
    net.eval()
    for data_2, targets_2 in test_loader:
        data_2 = data_2.to(device)
        targets_2 = targets_2.to(device)

        # Test set forward pass
        test_output_2 = net(data_2)

        # Previsões
        _, predicted = test_output_2.max(1)
        
        # Acumular acurácia
        total += targets_2.size(0)
        correct += (predicted == targets_2).sum().item()

        # Armazenar previsões e rótulos para F1 e matriz de confusão
        all_preds.extend(predicted.cpu().numpy())
        all_targets.extend(targets_2.cpu().numpy())

inference_tracker.epoch_end()   # fim da medição 

stats = compute_active_stats_from_activations(activations)
remove_hooks()

print(f"\n--- Resultados Detalhados no Conjunto de Teste ---")


# Calcular acurácia
print(f"Total correctly classified test set images: {correct}/{total}")
print(f"Test Set Accuracy: {100 * correct / total:.2f}%")

# Calcular precisão, recall e F1-score
precision, recall, f1 = calculate_metrics(all_targets, all_preds) 
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")

# Calcular e exibir a matriz de confusão
conf_matrix = confusion_matrix(all_targets, all_preds)
print("\nMatriz de Confusão:")
print(conf_matrix)

# Relatório detalhado por classe
print("\nClassification Report:")
print(classification_report(all_targets, all_preds, digits=4))

# Estatísticas de atividade dos neurônios
print("\n--- Métricas de Atividade dos Neurônios Ativos ---")
for layer in stats["layers"]:
    print(f"{layer}: média de neurônios ativos = {stats['active_mean_layer'][layer]:.2f}, "
          f"sparsity = {stats['sparsity_layer'][layer]*100:.1f}%")

print(f"\nMédia global de neurônios ativos por amostra: {stats['mean_global_active']:.2f}")

# Calcular sparsity global como média das sparsities por camada
global_sparsity = np.mean(list(stats['sparsity_layer'].values()))
print(f"Sparsity global: {global_sparsity*100:.1f}%")

# Estimativa simples de energia
# Assumindo custo de 1e-9 J/op
energy_per_op = 1e-9
print("\n--- Estimativa de Energia (simplificada) ---")
for layer in stats["layers"]:
    mean_active = stats['active_mean_layer'][layer]
    try:
        ops_per_activation = net._modules[layer].in_features  # se for Linear
    except:
        ops_per_activation = 1  # fallback
    E_layer = mean_active * ops_per_activation * energy_per_op
    print(f"{layer}: {E_layer:.2e} J")
# Out:
# CarbonTracker: INFO - Detected CPU: AMD Ryzen 5 5500U with Radeon Graphics
# CarbonTracker: WARNING - No matching TDP found for CPU: AMD Ryzen 5 5500U with Radeon Graphics. Using average TDP of 35.61W at 50% utilization as fallback.
# CarbonTracker: The following components were found: CPU with device(s) AMD Ryzen 5 5500U with Radeon Graphics.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: Live carbon intensity could not be fetched at detected location: São Paulo, São Paulo, BR. Defaulted to average carbon intensity for BR in 2023 of 98.35 gCO2/kWh. at detected location: São Paulo, São Paulo, BR.
# CarbonTracker:
# Predicted consumption for 1 epoch(s):
# 	Time:	0:01:05
# 	Energy:	0.001015308977 kWh
# 	CO2eq:	0.099853850936 g
# 	This is equivalent to:
# 	0.000928873032 km travelled by car
#
# --- Resultados Detalhados no Conjunto de Teste ---
# Total correctly classified test set images: 564/710
# Test Set Accuracy: 79.44%
# Precision: 0.58
# Recall: 0.58
# F1-score: 0.58
#
# Matriz de Confusão:
# [[535  74]
#  [ 72  29]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8814    0.8785    0.8799       609
#            1     0.2816    0.2871    0.2843       101
#
#     accuracy                         0.7944       710
#    macro avg     0.5815    0.5828    0.5821       710
# weighted avg     0.7961    0.7944    0.7952       710
#
#
# --- Métricas de Atividade dos Neurônios Ativos ---
# features.conv0: média de neurônios ativos = 61.20, sparsity = 4.4%
# features.denseblock1.denselayer1.conv1: média de neurônios ativos = 93.72, sparsity = 26.8%
# features.denseblock1.denselayer1.conv2: média de neurônios ativos = 31.03, sparsity = 3.0%
# features.denseblock1.denselayer2.conv1: média de neurônios ativos = 112.61, sparsity = 12.0%
# features.denseblock1.denselayer2.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock1.denselayer3.conv1: média de neurônios ativos = 125.65, sparsity = 1.8%
# features.denseblock1.denselayer3.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock1.denselayer4.conv1: média de neurônios ativos = 126.03, sparsity = 1.5%
# features.denseblock1.denselayer4.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock1.denselayer5.conv1: média de neurônios ativos = 125.29, sparsity = 2.1%
# features.denseblock1.denselayer5.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock1.denselayer6.conv1: média de neurônios ativos = 125.31, sparsity = 2.1%
# features.denseblock1.denselayer6.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.transition1.conv: média de neurônios ativos = 125.75, sparsity = 1.8%
# features.denseblock2.denselayer1.conv1: média de neurônios ativos = 123.70, sparsity = 3.4%
# features.denseblock2.denselayer1.conv2: média de neurônios ativos = 29.62, sparsity = 7.4%
# features.denseblock2.denselayer2.conv1: média de neurônios ativos = 127.05, sparsity = 0.7%
# features.denseblock2.denselayer2.conv2: média de neurônios ativos = 31.03, sparsity = 3.0%
# features.denseblock2.denselayer3.conv1: média de neurônios ativos = 126.32, sparsity = 1.3%
# features.denseblock2.denselayer3.conv2: média de neurônios ativos = 31.86, sparsity = 0.4%
# features.denseblock2.denselayer4.conv1: média de neurônios ativos = 124.21, sparsity = 3.0%
# features.denseblock2.denselayer4.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock2.denselayer5.conv1: média de neurônios ativos = 127.27, sparsity = 0.6%
# features.denseblock2.denselayer5.conv2: média de neurônios ativos = 31.82, sparsity = 0.6%
# features.denseblock2.denselayer6.conv1: média de neurônios ativos = 127.94, sparsity = 0.0%
# features.denseblock2.denselayer6.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock2.denselayer7.conv1: média de neurônios ativos = 126.26, sparsity = 1.4%
# features.denseblock2.denselayer7.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock2.denselayer8.conv1: média de neurônios ativos = 125.43, sparsity = 2.0%
# features.denseblock2.denselayer8.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock2.denselayer9.conv1: média de neurônios ativos = 128.00, sparsity = 0.0%
# features.denseblock2.denselayer9.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock2.denselayer10.conv1: média de neurônios ativos = 127.99, sparsity = 0.0%
# features.denseblock2.denselayer10.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock2.denselayer11.conv1: média de neurônios ativos = 127.55, sparsity = 0.3%
# features.denseblock2.denselayer11.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock2.denselayer12.conv1: média de neurônios ativos = 127.85, sparsity = 0.1%
# features.denseblock2.denselayer12.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.transition2.conv: média de neurônios ativos = 255.99, sparsity = 0.0%
# features.denseblock3.denselayer1.conv1: média de neurônios ativos = 127.32, sparsity = 0.5%
# features.denseblock3.denselayer1.conv2: média de neurônios ativos = 30.93, sparsity = 3.3%
# features.denseblock3.denselayer2.conv1: média de neurônios ativos = 122.30, sparsity = 4.5%
# features.denseblock3.denselayer2.conv2: média de neurônios ativos = 29.46, sparsity = 7.9%
# features.denseblock3.denselayer3.conv1: média de neurônios ativos = 127.45, sparsity = 0.4%
# features.denseblock3.denselayer3.conv2: média de neurônios ativos = 30.76, sparsity = 3.9%
# features.denseblock3.denselayer4.conv1: média de neurônios ativos = 125.44, sparsity = 2.0%
# features.denseblock3.denselayer4.conv2: média de neurônios ativos = 31.86, sparsity = 0.4%
# features.denseblock3.denselayer5.conv1: média de neurônios ativos = 125.49, sparsity = 2.0%
# features.denseblock3.denselayer5.conv2: média de neurônios ativos = 31.99, sparsity = 0.0%
# features.denseblock3.denselayer6.conv1: média de neurônios ativos = 127.27, sparsity = 0.6%
# features.denseblock3.denselayer6.conv2: média de neurônios ativos = 31.96, sparsity = 0.1%
# features.denseblock3.denselayer7.conv1: média de neurônios ativos = 127.17, sparsity = 0.7%
# features.denseblock3.denselayer7.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer8.conv1: média de neurônios ativos = 127.44, sparsity = 0.4%
# features.denseblock3.denselayer8.conv2: média de neurônios ativos = 31.99, sparsity = 0.0%
# features.denseblock3.denselayer9.conv1: média de neurônios ativos = 127.96, sparsity = 0.0%
# features.denseblock3.denselayer9.conv2: média de neurônios ativos = 31.87, sparsity = 0.4%
# features.denseblock3.denselayer10.conv1: média de neurônios ativos = 126.77, sparsity = 1.0%
# features.denseblock3.denselayer10.conv2: média de neurônios ativos = 31.97, sparsity = 0.1%
# features.denseblock3.denselayer11.conv1: média de neurônios ativos = 127.98, sparsity = 0.0%
# features.denseblock3.denselayer11.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer12.conv1: média de neurônios ativos = 127.78, sparsity = 0.2%
# features.denseblock3.denselayer12.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer13.conv1: média de neurônios ativos = 127.49, sparsity = 0.4%
# features.denseblock3.denselayer13.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer14.conv1: média de neurônios ativos = 126.50, sparsity = 1.2%
# features.denseblock3.denselayer14.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer15.conv1: média de neurônios ativos = 127.20, sparsity = 0.6%
# features.denseblock3.denselayer15.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer16.conv1: média de neurônios ativos = 127.94, sparsity = 0.0%
# features.denseblock3.denselayer16.conv2: média de neurônios ativos = 31.98, sparsity = 0.1%
# features.denseblock3.denselayer17.conv1: média de neurônios ativos = 127.53, sparsity = 0.4%
# features.denseblock3.denselayer17.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer18.conv1: média de neurônios ativos = 127.00, sparsity = 0.8%
# features.denseblock3.denselayer18.conv2: média de neurônios ativos = 31.99, sparsity = 0.0%
# features.denseblock3.denselayer19.conv1: média de neurônios ativos = 127.58, sparsity = 0.3%
# features.denseblock3.denselayer19.conv2: média de neurônios ativos = 31.98, sparsity = 0.1%
# features.denseblock3.denselayer20.conv1: média de neurônios ativos = 127.98, sparsity = 0.0%
# features.denseblock3.denselayer20.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer21.conv1: média de neurônios ativos = 128.00, sparsity = 0.0%
# features.denseblock3.denselayer21.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer22.conv1: média de neurônios ativos = 127.61, sparsity = 0.3%
# features.denseblock3.denselayer22.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer23.conv1: média de neurônios ativos = 127.99, sparsity = 0.0%
# features.denseblock3.denselayer23.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock3.denselayer24.conv1: média de neurônios ativos = 128.00, sparsity = 0.0%
# features.denseblock3.denselayer24.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.transition3.conv: média de neurônios ativos = 511.97, sparsity = 0.0%
# features.denseblock4.denselayer1.conv1: média de neurônios ativos = 122.79, sparsity = 4.1%
# features.denseblock4.denselayer1.conv2: média de neurônios ativos = 31.61, sparsity = 1.2%
# features.denseblock4.denselayer2.conv1: média de neurônios ativos = 125.28, sparsity = 2.1%
# features.denseblock4.denselayer2.conv2: média de neurônios ativos = 31.98, sparsity = 0.1%
# features.denseblock4.denselayer3.conv1: média de neurônios ativos = 121.92, sparsity = 4.8%
# features.denseblock4.denselayer3.conv2: média de neurônios ativos = 31.48, sparsity = 1.6%
# features.denseblock4.denselayer4.conv1: média de neurônios ativos = 119.89, sparsity = 6.3%
# features.denseblock4.denselayer4.conv2: média de neurônios ativos = 31.78, sparsity = 0.7%
# features.denseblock4.denselayer5.conv1: média de neurônios ativos = 125.97, sparsity = 1.6%
# features.denseblock4.denselayer5.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock4.denselayer6.conv1: média de neurônios ativos = 120.24, sparsity = 6.1%
# features.denseblock4.denselayer6.conv2: média de neurônios ativos = 31.97, sparsity = 0.1%
# features.denseblock4.denselayer7.conv1: média de neurônios ativos = 127.12, sparsity = 0.7%
# features.denseblock4.denselayer7.conv2: média de neurônios ativos = 31.99, sparsity = 0.0%
# features.denseblock4.denselayer8.conv1: média de neurônios ativos = 125.11, sparsity = 2.3%
# features.denseblock4.denselayer8.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock4.denselayer9.conv1: média de neurônios ativos = 126.39, sparsity = 1.3%
# features.denseblock4.denselayer9.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock4.denselayer10.conv1: média de neurônios ativos = 127.47, sparsity = 0.4%
# features.denseblock4.denselayer10.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock4.denselayer11.conv1: média de neurônios ativos = 126.12, sparsity = 1.5%
# features.denseblock4.denselayer11.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock4.denselayer12.conv1: média de neurônios ativos = 127.11, sparsity = 0.7%
# features.denseblock4.denselayer12.conv2: média de neurônios ativos = 31.99, sparsity = 0.0%
# features.denseblock4.denselayer13.conv1: média de neurônios ativos = 125.82, sparsity = 1.7%
# features.denseblock4.denselayer13.conv2: média de neurônios ativos = 31.99, sparsity = 0.0%
# features.denseblock4.denselayer14.conv1: média de neurônios ativos = 126.28, sparsity = 1.3%
# features.denseblock4.denselayer14.conv2: média de neurônios ativos = 32.00, sparsity = 0.0%
# features.denseblock4.denselayer15.conv1: média de neurônios ativos = 126.74, sparsity = 1.0%
# features.denseblock4.denselayer15.conv2: média de neurônios ativos = 31.99, sparsity = 0.0%
# features.denseblock4.denselayer16.conv1: média de neurônios ativos = 126.15, sparsity = 1.4%
# features.denseblock4.denselayer16.conv2: média de neurônios ativos = 31.99, sparsity = 0.0%
# classifier: média de neurônios ativos = 0.67, sparsity = 66.7%
#
# Média global de neurônios ativos por amostra: 10080.20
# Sparsity global: 1.8%
#
# --- Estimativa de Energia (simplificada) ---
# features.conv0: 6.12e-08 J
# features.denseblock1.denselayer1.conv1: 9.37e-08 J
# features.denseblock1.denselayer1.conv2: 3.10e-08 J
# features.denseblock1.denselayer2.conv1: 1.13e-07 J
# features.denseblock1.denselayer2.conv2: 3.20e-08 J
# features.denseblock1.denselayer3.conv1: 1.26e-07 J
# features.denseblock1.denselayer3.conv2: 3.20e-08 J
# features.denseblock1.denselayer4.conv1: 1.26e-07 J
# features.denseblock1.denselayer4.conv2: 3.20e-08 J
# features.denseblock1.denselayer5.conv1: 1.25e-07 J
# features.denseblock1.denselayer5.conv2: 3.20e-08 J
# features.denseblock1.denselayer6.conv1: 1.25e-07 J
# features.denseblock1.denselayer6.conv2: 3.20e-08 J
# features.transition1.conv: 1.26e-07 J
# features.denseblock2.denselayer1.conv1: 1.24e-07 J
# features.denseblock2.denselayer1.conv2: 2.96e-08 J
# features.denseblock2.denselayer2.conv1: 1.27e-07 J
# features.denseblock2.denselayer2.conv2: 3.10e-08 J
# features.denseblock2.denselayer3.conv1: 1.26e-07 J
# features.denseblock2.denselayer3.conv2: 3.19e-08 J
# features.denseblock2.denselayer4.conv1: 1.24e-07 J
# features.denseblock2.denselayer4.conv2: 3.20e-08 J
# features.denseblock2.denselayer5.conv1: 1.27e-07 J
# features.denseblock2.denselayer5.conv2: 3.18e-08 J
# features.denseblock2.denselayer6.conv1: 1.28e-07 J
# features.denseblock2.denselayer6.conv2: 3.20e-08 J
# features.denseblock2.denselayer7.conv1: 1.26e-07 J
# features.denseblock2.denselayer7.conv2: 3.20e-08 J
# features.denseblock2.denselayer8.conv1: 1.25e-07 J
# features.denseblock2.denselayer8.conv2: 3.20e-08 J
# features.denseblock2.denselayer9.conv1: 1.28e-07 J
# features.denseblock2.denselayer9.conv2: 3.20e-08 J
# features.denseblock2.denselayer10.conv1: 1.28e-07 J
# features.denseblock2.denselayer10.conv2: 3.20e-08 J
# features.denseblock2.denselayer11.conv1: 1.28e-07 J
# features.denseblock2.denselayer11.conv2: 3.20e-08 J
# features.denseblock2.denselayer12.conv1: 1.28e-07 J
# features.denseblock2.denselayer12.conv2: 3.20e-08 J
# features.transition2.conv: 2.56e-07 J
# features.denseblock3.denselayer1.conv1: 1.27e-07 J
# features.denseblock3.denselayer1.conv2: 3.09e-08 J
# features.denseblock3.denselayer2.conv1: 1.22e-07 J
# features.denseblock3.denselayer2.conv2: 2.95e-08 J
# features.denseblock3.denselayer3.conv1: 1.27e-07 J
# features.denseblock3.denselayer3.conv2: 3.08e-08 J
# features.denseblock3.denselayer4.conv1: 1.25e-07 J
# features.denseblock3.denselayer4.conv2: 3.19e-08 J
# features.denseblock3.denselayer5.conv1: 1.25e-07 J
# features.denseblock3.denselayer5.conv2: 3.20e-08 J
# features.denseblock3.denselayer6.conv1: 1.27e-07 J
# features.denseblock3.denselayer6.conv2: 3.20e-08 J
# features.denseblock3.denselayer7.conv1: 1.27e-07 J
# features.denseblock3.denselayer7.conv2: 3.20e-08 J
# features.denseblock3.denselayer8.conv1: 1.27e-07 J
# features.denseblock3.denselayer8.conv2: 3.20e-08 J
# features.denseblock3.denselayer9.conv1: 1.28e-07 J
# features.denseblock3.denselayer9.conv2: 3.19e-08 J
# features.denseblock3.denselayer10.conv1: 1.27e-07 J
# features.denseblock3.denselayer10.conv2: 3.20e-08 J
# features.denseblock3.denselayer11.conv1: 1.28e-07 J
# features.denseblock3.denselayer11.conv2: 3.20e-08 J
# features.denseblock3.denselayer12.conv1: 1.28e-07 J
# features.denseblock3.denselayer12.conv2: 3.20e-08 J
# features.denseblock3.denselayer13.conv1: 1.27e-07 J
# features.denseblock3.denselayer13.conv2: 3.20e-08 J
# features.denseblock3.denselayer14.conv1: 1.27e-07 J
# features.denseblock3.denselayer14.conv2: 3.20e-08 J
# features.denseblock3.denselayer15.conv1: 1.27e-07 J
# features.denseblock3.denselayer15.conv2: 3.20e-08 J
# features.denseblock3.denselayer16.conv1: 1.28e-07 J
# features.denseblock3.denselayer16.conv2: 3.20e-08 J
# features.denseblock3.denselayer17.conv1: 1.28e-07 J
# features.denseblock3.denselayer17.conv2: 3.20e-08 J
# features.denseblock3.denselayer18.conv1: 1.27e-07 J
# features.denseblock3.denselayer18.conv2: 3.20e-08 J
# features.denseblock3.denselayer19.conv1: 1.28e-07 J
# features.denseblock3.denselayer19.conv2: 3.20e-08 J
# features.denseblock3.denselayer20.conv1: 1.28e-07 J
# features.denseblock3.denselayer20.conv2: 3.20e-08 J
# features.denseblock3.denselayer21.conv1: 1.28e-07 J
# features.denseblock3.denselayer21.conv2: 3.20e-08 J
# features.denseblock3.denselayer22.conv1: 1.28e-07 J
# features.denseblock3.denselayer22.conv2: 3.20e-08 J
# features.denseblock3.denselayer23.conv1: 1.28e-07 J
# features.denseblock3.denselayer23.conv2: 3.20e-08 J
# features.denseblock3.denselayer24.conv1: 1.28e-07 J
# features.denseblock3.denselayer24.conv2: 3.20e-08 J
# features.transition3.conv: 5.12e-07 J
# features.denseblock4.denselayer1.conv1: 1.23e-07 J
# features.denseblock4.denselayer1.conv2: 3.16e-08 J
# features.denseblock4.denselayer2.conv1: 1.25e-07 J
# features.denseblock4.denselayer2.conv2: 3.20e-08 J
# features.denseblock4.denselayer3.conv1: 1.22e-07 J
# features.denseblock4.denselayer3.conv2: 3.15e-08 J
# features.denseblock4.denselayer4.conv1: 1.20e-07 J
# features.denseblock4.denselayer4.conv2: 3.18e-08 J
# features.denseblock4.denselayer5.conv1: 1.26e-07 J
# features.denseblock4.denselayer5.conv2: 3.20e-08 J
# features.denseblock4.denselayer6.conv1: 1.20e-07 J
# features.denseblock4.denselayer6.conv2: 3.20e-08 J
# features.denseblock4.denselayer7.conv1: 1.27e-07 J
# features.denseblock4.denselayer7.conv2: 3.20e-08 J
# features.denseblock4.denselayer8.conv1: 1.25e-07 J
# features.denseblock4.denselayer8.conv2: 3.20e-08 J
# features.denseblock4.denselayer9.conv1: 1.26e-07 J
# features.denseblock4.denselayer9.conv2: 3.20e-08 J
# features.denseblock4.denselayer10.conv1: 1.27e-07 J
# features.denseblock4.denselayer10.conv2: 3.20e-08 J
# features.denseblock4.denselayer11.conv1: 1.26e-07 J
# features.denseblock4.denselayer11.conv2: 3.20e-08 J
# features.denseblock4.denselayer12.conv1: 1.27e-07 J
# features.denseblock4.denselayer12.conv2: 3.20e-08 J
# features.denseblock4.denselayer13.conv1: 1.26e-07 J
# features.denseblock4.denselayer13.conv2: 3.20e-08 J
# features.denseblock4.denselayer14.conv1: 1.26e-07 J
# features.denseblock4.denselayer14.conv2: 3.20e-08 J
# features.denseblock4.denselayer15.conv1: 1.27e-07 J
# features.denseblock4.denselayer15.conv2: 3.20e-08 J
# features.denseblock4.denselayer16.conv1: 1.26e-07 J
# features.denseblock4.denselayer16.conv2: 3.20e-08 J
# classifier: 6.82e-07 J
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 98.34824 gCO2/kWh.

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Matriz de Confusão')
plt.show()
