# %% [markdown]
# # Dataset

# %% [markdown]
# ### Conection to Hugging Face

# %%
from datasets import load_dataset

# Carrega o dataset em modo streaming
dataset = load_dataset('alkzar90/NIH-Chest-X-ray-dataset', 
                        'image-classification',
                        streaming=True,
                        split='train')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 from datasets import load_dataset
#       3 # Carrega o dataset em modo streaming
# ----> 4 dataset = load_dataset('alkzar90/NIH-Chest-X-ray-dataset',
#       5                         'image-classification',
#       6                         streaming=True,
#       7                         split='train')
#
# File c:\Users\giueg\.virtualenvs\TCC_25-OGy0qkdu\Lib\site-packages\datasets\load.py:2081, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2079 # Return iterable dataset in case of streaming
#    2080 if streaming:
# -> 2081     return builder_instance.as_streaming_dataset(split=split)
# ...

# %% [markdown]
# ### Processing dataset

# %% [markdown]
# # SnnTorch

# %% [markdown]
# # PyTorchSpiking
